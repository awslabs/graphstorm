# %%
import json
import pyarrow.parquet as pq
import pandas as pd
import pyarrow as pa
import numpy as np

# %% [markdown]
# Get venues

# %%
f = open('mag_venues.txt', 'r')
venues = set()
for line in f.readlines():
    venue = json.loads(line)
    venues.add(venue['id'])
print(f'There are {len(venues)} venues')
venues = list(venues)
venues.sort()
df = pd.DataFrame({'id': venues})
table = pa.Table.from_pandas(df)
pq.write_table(table, 'mag_venue_id.parquet')
print("venue data type:", type(venues[0]))
venues = set(venues)
# Out:
# There are 53422 venues
# venue data type: <class 'int'>

# %% [markdown]
# Get affiliations

# %%
f = open('mag_affiliations.txt', 'r')
affs = list()
aff_names = list()
for line in f.readlines():
    aff = json.loads(line)
    affs.append(aff['id'])
    aff_names.append(aff['NormalizedName'])
print(f'There are {len(affs)} affiliations')
df = pd.DataFrame({'id': affs, 'name': aff_names})
table = pa.Table.from_pandas(df)
pq.write_table(table, 'mag_affs.parquet')

df = pd.DataFrame({'id': affs})
table = pa.Table.from_pandas(df)
pq.write_table(table, 'mag_aff_id.parquet')
print('Afflication data type:', type(affs[0]))
affs = set(affs)
# Out:
# There are 25776 affiliations
# Afflication data type: <class 'int'>

# %% [markdown]
# Get affiliation of authors and save the author-affiliation pairs in the parquet files. Not all authors have known affiliations.

# %%
full_authors = []
for i in range(5):
    f = open(f'mag_authors_{i}.txt', 'r')
    authors = []
    affs = []
    num_authors = 0
    for line in f.readlines():
        num_authors += 1
        author = json.loads(line)
        full_authors.append(author['id'])
        if 'last_known_aff_id' in author:
            authors.append(author['id'])
            affs.append(int(author['last_known_aff_id']))
            #assert author['last_known_aff_id'] in affs, f"{author['last_known_aff_id']} does not exist"
            #assert author['id'] not in author2aff
    df = pd.DataFrame({'author': authors, 'affiliation': affs})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_author2aff_{i}.parquet')
    print(f'There are {num_authors} authors and {len(authors)} of them have affiliations')
    
df = pd.DataFrame({'id': full_authors})
print('author ID data type:', type(full_authors[0]))
table = pa.Table.from_pandas(df)
pq.write_table(table, 'mag_author_id.parquet')
# Out:
# There are 29941623 authors and 9465011 of them have affiliations
# There are 53207043 authors and 12112687 of them have affiliations
# There are 59310755 authors and 9551575 of them have affiliations
# There are 55625205 authors and 5571860 of them have affiliations
# There are 45392524 authors and 6678088 of them have affiliations
# author ID data type: <class 'int'>

# %%
def parse_paper_file(i):
    f = open(f'mag_papers_{i}.txt', 'r')
    num_paper_venue = 0
    venue_ids = set()
    fos_set = set()

    paper_ids = []
    titles = []
    years = []
    paper2author = ([], [], [])
    paper2venue = ([], [])
    paper2fos = ([], [], [])
    paper2paper = ([], [])
    for line in f.readlines():
        paper = json.loads(line)
        if 'id' not in paper or 'title' not in paper or 'year' not in paper or 'authors' not in paper or len(paper['authors']) == 0:
            continue
        paper_ids.append(paper['id'])
        titles.append(paper['title'])
        years.append(paper['year'])
        for order, author in enumerate(paper['authors']):
            paper2author[0].append(paper['id'])
            paper2author[1].append(author['id'])
            paper2author[2].append(order)
        #if len(paper['authors']) == 0:
        #    print(paper)
        if 'venue' in paper:
            num_paper_venue += 1
            venue = paper['venue']
            if 'id' in venue:
                venue_ids.add(venue['id'])
                paper2venue[0].append(paper['id'])
                paper2venue[1].append(venue['id'])
                assert venue['id'] in venues
        if 'fos' in paper:
            for fos in paper['fos']:
                if fos['w'] > 0:
                    fos_set.add(fos['name'])
                    paper2fos[0].append(paper['id'])
                    paper2fos[1].append(fos['name'])
                    paper2fos[2].append(fos['w'])
        if 'references' in paper:
            for ref in paper['references']:
                paper2paper[0].append(paper['id'])
                paper2paper[1].append(ref)

    df = pd.DataFrame({'paper': paper_ids, 'title': titles, 'year': years})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_papers_{i}.parquet')
    print(f'There are {len(paper_ids)} papers in file {i}', flush=True)

    df = pd.DataFrame({'paper': paper2author[0], 'author': paper2author[1], 'order': paper2author[2]})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_paper2author_{i}.parquet')
    print(f'There are {len(paper2author[0])} paper-author pairs', flush=True)
    
    df = pd.DataFrame({'paper': paper2venue[0], 'venue': paper2venue[1]})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_paper2venue_{i}.parquet')
    print(f'There are {len(paper2venue[0])} paper-venue pairs', flush=True)
    
    df = pd.DataFrame({'paper': paper2fos[0], 'fos': paper2fos[1], 'w': paper2fos[2]})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_paper2fos_{i}.parquet')
    print(f'There are {len(paper2fos[0])} paper-fos pairs', flush=True)

    df = pd.DataFrame({'src_paper': paper2paper[0], 'dst_paper': paper2paper[1]})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_paper2paper_{i}.parquet')
    print(f'There are {len(paper2paper[0])} paper citations', flush=True)
    
    return num_paper_venue, venue_ids, fos_set

# %%
from graphstorm.gconstruct.utils import multiprocessing_data_read
data = multiprocessing_data_read([i for i in range(51)], num_processes=8, user_parser=parse_paper_file)

num_paper_venue = 0
venue_ids = set()
fos_set = set()
for i in data:
    num_paper_venue += data[i][0]
    venue_ids.update(data[i][1])
    fos_set.update(data[i][2])
# Out:
# There are 3662502 papers in file 7
# There are 4267728 papers in file 6
# There are 5328980 papers in file 0
# There are 5222259 papers in file 4
# There are 10595719 paper-author pairs
# There are 5549891 papers in file 1
# There are 1887447 paper-venue pairs
# There are 4423942 papers in file 5
# There are 10817771 paper-author pairs
# There are 1564146 paper-venue pairs
# There are 11204836 paper-author pairs
# There are 11406033 paper-author pairs
# There are 1210308 paper-venue pairs
# There are 1197241 paper-venue pairs
# There are 11747133 paper-author pairs
# There are 10617858 paper-author pairs
# There are 1261954 paper-venue pairs
# There are 1407684 paper-venue pairs
# There are 23221190 paper-fos pairs
# There are 7644442 papers in file 3
# There are 9056069 papers in file 2
# There are 25277429 paper-fos pairs
# There are 25070263 paper-fos pairs
# There are 22343061 paper-fos pairs
# There are 25623871 paper-fos pairs
# There are 24939618 paper-fos pairs
# There are 14587688 paper-author pairs
# There are 750743 paper-venue pairs
# There are 18009031 paper-author pairs
# There are 903264 paper-venue pairs
# There are 31892004 paper citations
# There are 28274452 paper citations
# There are 33210989 paper citations
# There are 50363810 paper citations
# There are 40841151 paper citations
# There are 20836061 paper-fos pairs
# There are 21363112 paper-fos pairs
# There are 39591298 paper citations
# There are 10958908 paper citations
# There are 16438891 paper citations
# There are 3358693 papers in file 8
# There are 3355440 papers in file 10
# There are 3355092 papers in file 9
# There are 11029515 paper-author pairs
# There are 3351987 papers in file 12
# There are 3354045 papers in file 11
# There are 3150090 paper-venue pairs
# There are 3354689 papers in file 13
# There are 11047167 paper-author pairs
# There are 3350715 papers in file 14
# There are 11034297 paper-author pairs
# There are 3147238 paper-venue pairs
# There are 3351153 papers in file 15
# There are 3147389 paper-venue pairs
# There are 11008158 paper-author pairs
# There are 11023241 paper-author pairs
# There are 11037909 paper-author pairs
# There are 3145515 paper-venue pairs
# There are 3146847 paper-venue pairs
# There are 11019668 paper-author pairs
# There are 3147648 paper-venue pairs
# There are 11009907 paper-author pairs
# There are 3144123 paper-venue pairs
# There are 26437317 paper-fos pairs
# There are 3145056 paper-venue pairs
# There are 26416682 paper-fos pairs
# There are 26419852 paper-fos pairs
# There are 26400545 paper-fos pairs
# There are 26427003 paper-fos pairs
# There are 26417376 paper-fos pairs
# There are 26412676 paper-fos pairs
# There are 26408155 paper-fos pairs
# There are 51054994 paper citations
# There are 51075614 paper citations
# There are 51015000 paper citations
# There are 51159786 paper citations
# There are 51100814 paper citations
# There are 51099883 paper citations
# There are 51133452 paper citations
# There are 51160731 paper citations
# There are 3348583 papers in file 16
# There are 11011140 paper-author pairs
# There are 3142677 paper-venue pairs
# There are 3261101 papers in file 17
# There are 2981404 papers in file 18
# There are 11011320 paper-author pairs
# There are 2966377 paper-venue pairs
# There are 26407709 paper-fos pairs
# There are 10947233 paper-author pairs
# There are 2967993 papers in file 20
# There are 2975662 papers in file 19
# There are 3489793 papers in file 21
# There are 2406237 paper-venue pairs
# There are 10932597 paper-author pairs
# There are 10931657 paper-author pairs
# There are 10991634 paper-author pairs
# There are 5472734 papers in file 23
# There are 2400956 paper-venue pairs
# There are 2404160 paper-venue pairs
# There are 5328904 papers in file 22
# There are 1622486 paper-venue pairs
# There are 25785632 paper-fos pairs
# There are 23858065 paper-fos pairs
# There are 12496115 paper-author pairs
# There are 963409 paper-venue pairs
# There are 12694706 paper-author pairs
# There are 51188585 paper citations
# There are 1087048 paper-venue pairs
# There are 23834440 paper-fos pairs
# There are 24774370 paper-fos pairs
# There are 23853131 paper-fos pairs
# There are 24916896 paper-fos pairs
# There are 53476786 paper citations
# There are 25729402 paper-fos pairs
# There are 60888656 paper citations
# There are 27083679 paper citations
# There are 57612590 paper citations
# There are 61072345 paper citations
# There are 32737185 paper citations
# There are 61006925 paper citations
# There are 5363502 papers in file 24
# There are 13234092 paper-author pairs
# There are 1932526 paper-venue pairs
# There are 27190477 paper-fos pairs
# There are 5361900 papers in file 25
# There are 35083640 paper citations
# There are 4610623 papers in file 26
# There are 14648231 paper-author pairs
# There are 5751196 paper-author pairs
# There are 3414853 paper-venue pairs
# There are 3975109 paper-venue pairs
# There are 5108432 papers in file 31
# There are 5107591 papers in file 27
# There are 27295286 paper-fos pairs
# There are 32296630 paper-fos pairs
# There are 2678797 paper citations
# There are 6821509 papers in file 29
# There are 14166086 paper-author pairs
# There are 9362385 paper-author pairs
# There are 1619434 paper-venue pairs
# There are 3328012 paper-venue pairs
# There are 5408057 papers in file 30
# There are 6202016 papers in file 28
# There are 33106735 paper citations
# There are 15086871 paper-author pairs
# There are 1980632 paper-venue pairs
# There are 14034319 paper-author pairs
# There are 24873057 paper-fos pairs
# There are 15515329 paper-author pairs
# There are 1936741 paper-venue pairs
# There are 31422648 paper-fos pairs
# There are 4093932 paper-venue pairs
# There are 12237465 paper citations
# There are 29420943 paper-fos pairs
# There are 31469870 paper citations
# There are 25479837 paper-fos pairs
# There are 32377556 paper-fos pairs
# There are 35977546 paper citations
# There are 33525345 paper citations
# There are 17778331 paper citations
# There are 5285308 papers in file 32
# There are 15594577 paper-author pairs
# There are 1612645 paper-venue pairs
# There are 24800609 paper-fos pairs
# There are 27520504 paper citations
# There are 5395750 papers in file 33
# There are 15745574 paper-author pairs
# There are 1290643 paper-venue pairs
# There are 24819391 paper-fos pairs
# There are 5036677 papers in file 34
# There are 24308298 paper citations
# There are 16748261 paper-author pairs
# There are 1190255 paper-venue pairs
# There are 24856637 paper-fos pairs
# There are 26300688 paper citations
# There are 4870900 papers in file 35
# There are 5178531 papers in file 36
# There are 5213797 papers in file 37
# There are 5213278 papers in file 38
# There are 15540122 paper-author pairs
# There are 5213878 papers in file 39
# There are 1000029 paper-venue pairs
# There are 15013618 paper-author pairs
# There are 12327537 paper-author pairs
# There are 12931 paper-venue pairs
# There are 1806048 paper-venue pairs
# There are 12337920 paper-author pairs
# There are 13173 paper-venue pairs
# There are 12319853 paper-author pairs
# There are 12943 paper-venue pairs
# There are 22769078 paper-fos pairs
# There are 25930379 paper-fos pairs
# There are 23252718 paper-fos pairs
# There are 25927598 paper-fos pairs
# There are 5430594 paper citations
# There are 25928290 paper-fos pairs
# There are 23206020 paper citations
# There are 5412490 paper citations
# There are 5212124 papers in file 40
# There are 5375773 paper citations
# There are 33171646 paper citations
# There are 12320173 paper-author pairs
# There are 12873 paper-venue pairs
# There are 25921085 paper-fos pairs
# There are 5400783 paper citations
# There are 5212848 papers in file 41
# There are 12334500 paper-author pairs
# There are 12935 paper-venue pairs
# There are 25918441 paper-fos pairs
# There are 5378709 paper citations
# There are 4956229 papers in file 42
# There are 13224310 paper-author pairs
# There are 651407 paper-venue pairs
# There are 24272686 paper-fos pairs
# There are 17280285 paper citations
# There are 4661356 papers in file 43
# There are 4490867 papers in file 46
# There are 4904229 papers in file 44
# There are 14537863 paper-author pairs
# There are 1615534 paper-venue pairs
# There are 3300437 papers in file 50
# There are 4867803 papers in file 47
# There are 13324924 paper-author pairs
# There are 4834975 papers in file 45
# There are 14042296 paper-author pairs
# There are 1071650 paper-venue pairs
# There are 713865 paper-venue pairs
# There are 10717870 paper-author pairs
# There are 21361169 paper-fos pairs
# There are 1061145 paper-venue pairs
# There are 14291276 paper-author pairs
# There are 14631797 paper-author pairs
# There are 1268832 paper-venue pairs
# There are 24007125 paper-fos pairs
# There are 1245854 paper-venue pairs
# There are 13946192 paper-fos pairs
# There are 23923532 paper-fos pairs
# There are 12685296 paper citations
# There are 35838787 paper citations
# There are 22054291 paper citations
# There are 4989878 papers in file 48
# There are 23614785 paper-fos pairs
# There are 22762436 paper-fos pairs
# There are 18540388 paper citations
# There are 5579532 papers in file 49
# There are 15779380 paper-author pairs
# There are 23769289 paper citations
# There are 1564036 paper-venue pairs
# There are 26625613 paper citations
# There are 17508917 paper-author pairs
# There are 1547869 paper-venue pairs
# There are 23454580 paper-fos pairs
# There are 24395338 paper-fos pairs
# There are 27172944 paper citations
# There are 29466019 paper citations

# %%
print(f'There are {num_paper_venue} papers that have venues.')
print(f'There are {len(venue_ids)} venues with IDs')
print(f'There are {len(fos_set)} topic fields')
# Out:
# There are 143630713 papers that have venues.
# There are 53422 venues with IDs
# There are 275021 topic fields

# %%
df = pd.DataFrame({'id': np.array(list(fos_set))})
table = pa.Table.from_pandas(df)
print('fos data type:', type(list(fos_set)[0]))
pq.write_table(table, 'mag_fos.parquet')
# Out:
# fos data type: <class 'str'>

# %% [markdown]
# The code below creates venues as labels of paper nodes.

# %%
v_papers = []
venues = []
for i in range(51):
    table = pd.read_parquet(f'mag_paper2venue_{i}.parquet')
    v_papers.append(table['paper'].to_numpy())
    venues.append(table['venue'].to_numpy())
v_papers = np.concatenate(v_papers)
venues = np.concatenate(venues)

# %%
uniq_venues, v_cnts = np.unique(venues, return_counts=True)

# %%
common_venue_map = {venue: i for i, venue in enumerate(uniq_venues[v_cnts > 10000].tolist())}

# %%
v_papers1 = []
venues1 = []
for pid, v in zip(v_papers, venues):
    if v in common_venue_map:
        v_papers1.append(pid)
        venues1.append(common_venue_map[v])

# %%
p2v_map = {paper: venue for paper, venue in zip(v_papers1, venues1)}

# %%
import math
num_labels = 0
for i in range(51):
    table = pd.read_parquet(f'mag_papers_{i}.parquet')
    venues = []
    for paper in table['paper'].to_numpy():
        if paper in p2v_map:
            venues.append(p2v_map[paper])
            num_labels += 1
        else:
            venues.append(math.nan)
    df = pd.DataFrame({'paper': table['paper'], 'title': table['title'],
                       'year': table['year'], 'venue': np.array(venues)})
    table = pa.Table.from_pandas(df)
    pq.write_table(table, f'mag_papers_with_labels_{i}.parquet')
    print(f'There are {len(venues)} papers in file {i}', flush=True)
    print(f'There are {num_labels} labels so far.')
# Out:
# There are 5328980 papers in file 0
# There are 358029 labels so far.
# There are 5549891 papers in file 1
# There are 698300 labels so far.
# There are 9056069 papers in file 2
# There are 920280 labels so far.
# There are 7644442 papers in file 3
# There are 1106205 labels so far.
# There are 5222259 papers in file 4
# There are 1475060 labels so far.
# There are 4423942 papers in file 5
# There are 1890023 labels so far.
# There are 4267728 papers in file 6
# There are 2461230 labels so far.
# There are 3662502 papers in file 7
# There are 3229396 labels so far.
# There are 3358693 papers in file 8
# There are 4792230 labels so far.
# There are 3355092 papers in file 9
# There are 6354551 labels so far.
# There are 3355440 papers in file 10
# There are 7917339 labels so far.
# There are 3354045 papers in file 11
# There are 9478565 labels so far.
# There are 3351987 papers in file 12
# There are 11039437 labels so far.
# There are 3354689 papers in file 13
# There are 12600462 labels so far.
# There are 3350715 papers in file 14
# There are 14159216 labels so far.
# There are 3351153 papers in file 15
# There are 15718926 labels so far.
# There are 3348583 papers in file 16
# There are 17278005 labels so far.
# There are 3261101 papers in file 17
# There are 18708512 labels so far.
# There are 2981404 papers in file 18
# There are 19730443 labels so far.
# There are 2975662 papers in file 19
# There are 20751005 labels so far.
# There are 2967993 papers in file 20
# There are 21771526 labels so far.
# There are 3489793 papers in file 21
# There are 22399866 labels so far.
# There are 5328904 papers in file 22
# There are 22754541 labels so far.
# There are 5472734 papers in file 23
# There are 23053031 labels so far.
# There are 5363502 papers in file 24
# There are 23777030 labels so far.
# There are 5361900 papers in file 25
# There are 25205918 labels so far.
# There are 4610623 papers in file 26
# There are 25590307 labels so far.
# There are 5107591 papers in file 27
# There are 26213271 labels so far.
# There are 6202016 papers in file 28
# There are 27632696 labels so far.
# There are 6821509 papers in file 29
# There are 28221869 labels so far.
# There are 5408057 papers in file 30
# There are 28831725 labels so far.
# There are 5108432 papers in file 31
# There are 29344231 labels so far.
# There are 5285308 papers in file 32
# There are 29948955 labels so far.
# There are 5395750 papers in file 33
# There are 30369908 labels so far.
# There are 5036677 papers in file 34
# There are 30792010 labels so far.
# There are 4870900 papers in file 35
# There are 31111743 labels so far.
# There are 5178531 papers in file 36
# There are 31766794 labels so far.
# There are 5213797 papers in file 37
# There are 31770942 labels so far.
# There are 5213278 papers in file 38
# There are 31775079 labels so far.
# There are 5213878 papers in file 39
# There are 31779174 labels so far.
# There are 5212124 papers in file 40
# There are 31783231 labels so far.
# There are 5212848 papers in file 41
# There are 31787340 labels so far.
# There are 4956229 papers in file 42
# There are 32017317 labels so far.
# There are 4661356 papers in file 43
# There are 32553848 labels so far.
# There are 4904229 papers in file 44
# There are 32808718 labels so far.
# There are 4834975 papers in file 45
# There are 33423607 labels so far.
# There are 4490867 papers in file 46
# There are 33938914 labels so far.
# There are 4867803 papers in file 47
# There are 34397539 labels so far.
# There are 4989878 papers in file 48
# There are 34879026 labels so far.
# There are 5579532 papers in file 49
# There are 35438490 labels so far.
# There are 3300437 papers in file 50
# There are 35849264 labels so far.

# %%
print(len(p2v_map))
# Out:
# 35849264

# %%
table = pd.read_parquet(f'mag_papers_with_labels_0.parquet')

# %%
table['venue'].dtype
# Out:
# dtype('float64')
